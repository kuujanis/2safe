# %% [markdown]
# Анализ данных по

# %%
import pandas as pd
import geopandas as gpd

# %%
df = pd.read_csv('data/data-61762-2025-09-25.csv', sep=';')
df.head()
# Out:
# /var/folders/_v/2dw5txt559lgdgypbyznc5mm0000gn/T/ipykernel_4913/4037688511.py:1: DtypeWarning: Columns (0,1,4,9,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/data-61762-2025-09-25.csv', sep=';')
#    global_id   ID      PillarMark         PillarType             LightsNumber  \
# 0  global_id  Код     Марка опоры          Тип опоры  Количество светильников
# 1  170458093    1  ОП-400-8,5 оц.  Опора стандартная                        1
# 2  170458094    2  ОП-400-8,5 оц.  Опора стандартная                        1
# 3  170458095    3  ОП-400-8,5 оц.  Опора стандартная                        1
# 4  170458096    4  ОП-400-8,5 оц.  Опора стандартная                        1
#
#          Status                                OnTerritoryOfMoscow  \
# 0        Статус  Объект расположен в пределах границ города Москвы
# 1  эксплуатация                                                 да
# 2  эксплуатация                                                 да
# 3  эксплуатация                                                 да
# 4  эксплуатация                                                 да
#
#                                    AdmArea        District           Year  \
# 0                   Административный округ           Район  Год установки
# 1  Северо-Восточный административный округ  район Бибирево           2003
# 2  Северо-Восточный административный округ  район Бибирево           2003
# 3  Северо-Восточный административный округ  район Бибирево           2003
# 4  Северо-Восточный административный округ  район Бибирево           2003
#
#   BalanceHolderName                          OperationOrganizationName  \
# 0  Балансодержатель  Организация, ответственная за эксплуатацию опо...
# 1               NaN                                                NaN
# 2               NaN                                                NaN
# 3               NaN                                                NaN
# 4               NaN                                                NaN
#
#                                              geoData  geodata_center  \
# 0                                            geoData  geodata_center
# 1  {coordinates=[37.609186415, 55.902418871], typ...             NaN
# 2  {coordinates=[37.608862778, 55.902201086], typ...             NaN
# 3  {coordinates=[37.608572113, 55.901982795], typ...             NaN
# 4  {coordinates=[37.608164794, 55.901698737], typ...             NaN
#
#    Unnamed: 14
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
list(df['PillarMark'].unique())
# Out:
# ['Марка опоры',
#  'ОП-400-8,5 оц.',
#  'ОМ-5',
#  'СФ-28-02 оц. «Новые башни МР»',
#  'О6',
#  'ОС-0,3-9,0 оц.',
#  'ОС-0,4-9,0',
#  'СЦС-0,8-10,0',
#  'О5',
#  'СП-400-8,5/10,5-01 оц.',
#  'СП-400-8,5/10,5-02 оц.',
#  'СП-400-9,0/11,0-01 оц.',
#  'СП-400-9,0/11,0-02 оц.',
#  'СФ-29-02 оц. «Русские башни»',
#  'ОС-0,7-9,0 оц.',
#  'СП-700-8,5/10,5-01 оц.',
#  'ОС-0,4-9,0 оц.',
#  'ОС-0,7',
#  'ОСЦ-1,5-9,0',
#  'О7',
#  'СП-700-9,0/11,0-01 оц.',
#  'ОСЦ-0,8-9,0 оц.',
#  'ОСЦ-1,3-9,0 оц.',
#  'ОСЦ-0,7-9,0 оц.',
#  'ОКК SP-2-9 оц.',
#  'ОП-700-8,5',
#  'ОМ-6',
#  'ОС-0,5-9,0',
#  'ОКК-6-1 Проспект',
#  'О3',
#  'Опора прист. (Б)',
#  'ОС-0,3-9,0',
#  'ОС-0,4-8,5 к оц.',
#  'СФ-28-02 оц. «НГС»',
#  'СЦС-0,8',
#  'ОГК-5',
#  'ОМ-5 оц.',
#  'СП-400-9,5/11,0-01 оц.',
#  'СЦС-1,2-10,0',
#  'ОКК SP-2-7 оц.',
#  'ОГК-5 ф',
#  'СП-700-9,0/11,0-02 оц.',
#  'ОС-0,4-8,5 оц.',
#  'ОГК-4 оц.',
#  'ОО-7-Р-3-1',
#  'Т-1-М',
#  'ОО-4,5-Т-1-1',
#  'СП-700-8,5/10,5-02 оц',
#  'ОКК-8 Аллея оц.',
#  'Бульвар BLV-40 оц.',
#  'ОСМ-0,4',
#  'СП-400-9,0/11,0 оц.',
#  'СФ оц. «Новые башни МР»',
#  'СЦС',
#  'ОС-0,7-9,0',
#  'ОП-400-8,5',
#  'ОКК SP-2-9-212 оц.',
#  'ОМ-7',
#  'СЦС-0,5',
#  'СП-400-8,5/11,0-02оц',
#  'ОСФ-700-9,0 оц.',
#  'ОКК Проспект PSKT-90-1 оц.',
#  'СП-400-9,0 оц.',
#  'ОС-0,6-9,0',
#  'Опора прист. (М)',
#  'ОЖБ',
#  'О5 промежут.',
#  'МГТ',
#  'ОС-0,9-9,0',
#  'ОС-0,9-9,0 оц.',
#  'ОС-0,8-9,0',
#  'ОС-0,5',
#  'ОСЦГ-0,9-9,0',
#  'ОТ2-4,5-1,2',
#  'секция ОДН',
#  'Опора прист. оц.',
#  'ОСЦ-0,8',
#  'ОКК SP-9-9-212 оц. Смарт',
#  'ОП-700-8,5 оц.',
#  'ОККс-0,4-9,0 оц.',
#  'ОККэ-9 оц.',
#  'промежут. (Б)',
#  'ОТ2-4,0-1,5 оц.',
#  'Проспект-9,0-95/219 оц.',
#  'СП-700-9,0/11,0 оц.',
#  'Проспект-9,0-95/219 оц.МФО',
#  'Торшер',
#  'ОТ2-4,5-1,5 оц.',
#  'Опора МОЭСК',
#  'СЦС-0,6',
#  'ОП-700',
#  'ОС-0,8-9,0 оц.',
#  'Торшер «Платан-1»',
#  'НФГ-6,0-0,2 оц.',
#  'ОП-400',
#  'ОМ-4',
#  'СФ оц. «Русские башни»',
#  'ОСЦГ-1,2',
#  'ОСЦ-0,7-9,0',
#  'ОСЦ-1,3',
#  'ОСЦ-1,5',
#  'СП-700-9,0 оц.',
#  'СФ-28-02 оц. «Опоры Столицы»',
#  'ОС-0,7-9,0-2В',
#  'Осв. система Гарда-45',
#  'Осв. система Верста-90',
#  'СП-700-9,0/11,0-03 оц.',
#  'ОС-0,6',
#  'СФ оц. «Опоры Столицы»',
#  'ОС-1,5-9,0',
#  'Торшер Сокол-1',
#  'ОС-0,3',
#  'СФ-400-9,0 оц.',
#  'ПФГ-8,0-0,2 оц.',
#  'промежут. (М)',
#  'ОСЦ-1,3-9,0',
#  'СФ-700-9,0-01 оц.',
#  'СП-400-8,5/11,0-01оц',
#  'Торшер «Платан-2»',
#  'КО-9000/245',
#  'Торшер «Платан-1» оц.',
#  'ОП-300-8,5',
#  'Т-3-М',
#  'КО-1-1',
#  'О6 промежут.',
#  'ОГКф-5 оц.',
#  'СЦ-1,2',
#  'ОКК-4,0-02 оц.',
#  'КО-9000/245 оц.',
#  'ОМ-Т',
#  'Смарт ТSM-6,0-4,0/4,0-1К',
#  'ОС-0,4 ук.',
#  'СФГ-400-9,0-02оц',
#  'ОКК-9 Проспект оц.',
#  'ОП-300-8,5 оц.',
#  'ОП-700-9,0 оц.',
#  'СЦС-0,6-10,0',
#  'Т-2-М',
#  'ОКК SP-2-8 оц.',
#  'ОКК SP-9-8 МФО оц.',
#  'ОМ-6 оц.',
#  'ОП-400-9,0 оц.',
#  'СФ-28-02 оц. «Вертикаль»',
#  'Опора Проспект-9 оц.',
#  'Т-20 спец.',
#  'ОС-0,4',
#  'ОКК Проспект PSKT-80-1',
#  'ОГКС-0,4-9,0 оц.',
#  'Н-4,2',
#  'Фонарь Ф-7',
#  'ОКК SP-9-6-147 оц.',
#  'ОС-0,9-9,0-2В',
#  'ОС-1,5-9,0-2В',
#  'Смарт ТSM-5,0-3,0/4,0-1К',
#  'СФ-400-9,0-02 оц.',
#  'НФГ-9,0-0,2 оц.',
#  'Дер. (МОЭСК)',
#  'ОСЦ-0,4',
#  'СЦ-0,8-10,0',
#  'НФК-6,0-0,2 оц.',
#  'ОС-0,8',
#  'ОДН без. Об',
#  'ОСЦ-0,8-10,0',
#  'ОСЦ-0,5-9,0',
#  'СФ-700-9,0/11-02 оц.',
#  'ОСЦ-0,4-9,0 оц.',
#  'ОГКС-0,7-9,0 оц.',
#  'НФ-5,0-05-оц.',
#  'ОС-0,8-9,0 оц.-Т',
#  'ОС-1,5-9,0 оц.-Т',
#  'СП-400-8,5 оц.',
#  'ОМ-5 ук.',
#  'ОДН «НГС»',
#  'НОСВ 01.010',
#  'ОБ (МОЭСК)',
#  'ОСЦ-1,3-11,0',
#  'КО-2-4,0 ф',
#  'ОМ-6-Т',
#  'О6-Т',
#  'О7-Т',
#  'ОСЦ-1,3-9,0-Т',
#  'ОМ-7-Т',
#  'ОМ нестанд.',
#  'ОС-1,1-11,0',
#  'О7 промежут.',
#  'О2',
#  'ТП-400-9,0/11,0-0,1 оц.',
#  'СФ-400-5,0-0,1 оц.',
#  'ФМ-05 (Т)',
#  'ОСФ-0,4-9,0 оц.',
#  'ОС-0,3-9,0 ф оц.',
#  'ОС-1,0-11,0 оц.',
#  'ОСЦ-0,7',
#  'ОКК Проспект PSKT-60',
#  'Бульвар BLV-45 оц.',
#  'СФ-28-02 оц. «Прайм Телеком»',
#  'Опора Вертикаль',
#  'ОС-1,3',
#  'ОС-1,5-9,0 оц.',
#  'ОСЦ-0,4-9,0',
#  'ОС-0,4-13,0',
#  'ОПФ-400-8,5 оц.',
#  'ОПФ-700-8,5 оц.',
#  'ТП-400-8,5/10,5-0,1 оц.',
#  'СЦС-0,8-12,0',
#  'ОПФГ-10',
#  'ОП-700-9,0',
#  'ОС-0,5-9,0 оц.',
#  'ОП-400-9,0',
#  'ОС оц.',
#  'ОС-0,4-11,0',
#  'ОС-0,3 надставка «Русские башни»',
#  'ОС-0,4-4,5',
#  'ОКК Проспект-90-СИП-400',
#  'СФ-400-8,5-01 оц.',
#  'СП-400-4,5-01 оц.',
#  'ОСЦ-0,6',
#  'ОКК SP-3-6 оц.',
#  'Проспект-9,0-75/195 оц.',
#  'ОМ-5 ф',
#  'ОСФ-0,7-9,0 оц.',
#  'Опора 2-го назн. (МГТ)',
#  'ОККс-8,0-70/182 оц. Аллея',
#  'ОС',
#  'НФГ-5,0-0,2 оц.',
#  'ОККО Легато-7,0-6 оц.',
#  'ОТ2(60)-5,0-1,5 ф. оц.',
#  'ОМ-5-Т',
#  'ОМ',
#  'Бульвар BLV50 оц.',
#  'ОС-0,4-16,0',
#  'СЦС-1,2',
#  'СФ-700-9,0-02 оц.',
#  'ОС-0,4-17,5',
#  'ОС-1,1-13,0',
#  'СФ-400-9,0/11-02 оц.',
#  'Ф-2-П',
#  'СВН-9',
#  'ОКК SP-3-4,5 оц.',
#  'Н-30',
#  'ОКК SP-9-7 оц.',
#  'СП-400/5,9-0,1 оц.',
#  'ОС-0,3-6,0 ук.',
#  'ФМ-05',
#  'ФМ-05 вк.',
#  'ОС-0,3 ф',
#  'ФМ-06',
#  'НФГ-8,0-0,2 оц.',
#  'СФ-700-9,0/11,0-02 оц.',
#  'ОС-0,4 ф ук.',
#  'СФ-700-5,0/7,0-02 оц.',
#  'ОС-1,5',
#  'МС-9Г-0,4 оц.',
#  'МГФ-30-М-(500)-II-8-ц',
#  'МГФ-30-М-(500)-II-6-ц',
#  'МГФ-20-М-(500)-II-4-ц',
#  'МГФ-30-М-(500)-II-5-ц',
#  'ОС-0,4-9,0 ф оц.',
#  'Н-30-6',
#  'СФГ-0,4-9,0 оц.',
#  'ОПФ-400-9,0 оц.',
#  'Н-20-4',
#  'Н-20-6',
#  'Н-30-10',
#  'Н-20-10',
#  'Торшер «Лотос»',
#  'СКОПП Легато-7,0-4 оц.',
#  'СФ-28-02 оц. «Быстротел»',
#  'ОСЦ-1,5-9,0 оц.',
#  'ОКК SP-9-9-310 оц.',
#  'Торшер парковый',
#  'ОМ-8',
#  'ОТ2(60)-3,0-1,0 оц.',
#  'Торшер Арбат ARB-40-1',
#  'ОС-1,0-11,0',
#  'Проспект-6,0-60/144 оц.',
#  'Проспект-9,0-60/186 оц.',
#  'СФ-400-9,0-01 оц.',
#  'ОПГ-5 ф оц.',
#  'ОС-0,6-11,0',
#  'ОСТ-700-8,5/10,5-01 оц.',
#  'ОС-0,7-9,0 ф оц.',
#  'ОС-0,7-11,0 оц.',
#  'ОС-0,7-11,0',
#  'ОС-0,8-9,0-2В',
#  'ОМ-13',
#  'СВН',
#  'НФГ-4,0-0,2 оц.',
#  'ОКК-8,0-02 оц.',
#  'О5-Т',
#  'Торшер «Виконт»',
#  'НФ-4,0-0,2 оц.',
#  'ОС-0,5-8,5 оц.',
#  'СФ-28-02 оц. «Русские башни»',
#  'СП-400 оц.',
#  'ОКК SP-3-4 оц.',
#  'ОС-0,7-9,0-Т',
#  'СП-300-9,0/11,0-01оц',
#  'О4',
#  'СП-400-8,5/10,5-01 оц. промежут.',
#  'СП-400-9,0 и надставка «Русские башни»',
#  'СП-400-9,0 надставка «Опоры Столицы»',
#  'СФГ-700-9,0-02 оц.',
#  'ОМ-9-Т',
#  'Торшер Сокол-1 оц.',
#  'Торшер «Сокол-1»оц.',
#  'ОСЦ-0,9-9,0',
#  'Бульвар BLV2-40 оц.',
#  'ОМ-3',
#  'Бульвар-4,0-60/124',
#  'Торшер СИСИ-1',
#  'Торшер СИСИ-2',
#  'ОКК SP-1-9 оц.',
#  'ОС-0,7-9,0 к оц.',
#  'ОКК-7 ф оц.',
#  'ОС-0,4 надставка «Русские башни»',
#  'ОБК',
#  'Опора 2-го назн.',
#  'СКОПП Легато-7,0-2 оц.',
#  'Бульвар BLV60 оц.',
#  'Опора МОЭСК (Б)',
#  'О5 (МОЭСК)',
#  'ОС-0,3 ук. оц.',
#  'ОС-0,4 ук. оц.',
#  'СЦ-2-2',
#  'ОКК-4,5 оц.',
#  'Секция ОДН',
#  'ВМО-30',
#  'ОС-0,3-9,0 ук.оц.',
#  'ОПФГ-9 оц.',
#  'ОТ2ф-3,5-1,0',
#  'Торшер Арбат-4,0 оц.',
#  'ОПФГ-5',
#  'КО-1-1-5,0-12',
#  'МК-5Г-60',
#  'КК-5Г-75',
#  'ОСФ-0,4-9,0-02 оц.',
#  'СВ',
#  'ОКК-9,0 оц.',
#  'ОКК-9,0 ф оц.',
#  'Смарт CSM-6,0-4,0/4,0-2Р оц.',
#  'ОСФ-0,4-9,0',
#  'ОПФГ-6 оц.',
#  'ОПФГ-10 оц.',
#  'ФМ-06(Т)',
#  'СФ-400-9,0/11-01 оц.',
#  'МосМетро',
#  'Опора декор.фонаря',
#  'СОФ-8 оц.',
#  'СП-400-4,0/6,0 оц.',
#  'ОГК-9 оц.',
#  'ОС-1,3-11,0',
#  'СЦС-0,65',
#  'СЦС-0,6-8,0',
#  'О3гр',
#  'ОПФГ-4',
#  'Торшер «Виконт-2»',
#  'ОС-0,5 промежут.',
#  'Т-2-Л',
#  'ОСЦ-2,4-9,0',
#  'ОКК-5,0-02 оц.',
#  'КУТБ 03.000 оц.',
#  'Торшер «Адамант-2»',
#  'НФ-5,0-02 оц.',
#  'ОМ-13-Т',
#  'ОС-1,1-13,0 ф оц.',
#  'Торшер «Адамант-1»',
#  'ОКК-8 Проспект оц.',
#  'ОС-0,9-9,0-Т',
#  'ОС-1,1-9,0 оц.',
#  'ОКК Проспект PSKT-90/МФО оц.',
#  'ОКК SP-2-9-310 оц.',
#  'ОКК SP-6-8 оц.',
#  'ОКК Проспект PSKT-60/MFO',
#  'СПГ-400-7,5/10-02 оц.',
#  'ОС-0,7-9,0 оц. промежут.',
#  'ОКК SP-3-5 оц.',
#  'СФГ-400-9,0-02 оц.',
#  'СП-400-8,5/10,5-01',
#  'СП-400-5,0/7,0-01 оц.',
#  'ОС-0,5-9,0 ф',
#  'ОМ-3 промежут.',
#  'Опора парк.',
#  'Фонарь литой Тип3 H-90/4',
#  'ОГК-5 оц.',
#  'Фонарь литой Тип1 H-40/2',
#  'Фонарь литой Тип4 H-60/5',
#  'Фонарь литой Тип2 H-40/1',
#  'Проспект-8,0-60/156 оц.',
#  'ОКК-9,0-75/195',
#  'ОКК SP-1-4 оц.',
#  'МФО-9,0-111/219',
#  'СЦ-1,2-10,0',
#  'СЦС-1,0-10,0',
#  'ОГК-9 ф оц.',
#  'Осв. система Верста-60',
#  'ОМ-5 промежут.',
#  'Бульвар-6,0-60/145',
#  'НФГ-4,0-02-оц.',
#  'ОКК SP-10-7-2 оц. СКОПП',
#  'ОКК-4,5 оц. Бульвар',
#  'ОТ2ф-6,0-3,5',
#  'ОККс-8,0 Аллея',
#  'ОКК-9 Проспект СИП оц.',
#  'СФГ-400-9,0-01оц',
#  'Ф-1-П',
#  'ОС-0,3-9,0 промеж.',
#  'ОКК SP-9-6 оц.',
#  'Торшер 1.ТО1.10.0.V09 д/1',
#  'Торшер «Платан-4»',
#  'ОТ1-9-2',
#  'Н-30-8',
#  'ОКК SP-10-7-4 оц. СКОПП',
#  'ВМО-25/6',
#  'ОГКф-10 с фунд оц.',
#  'ОПФГ-5 оц.',
#  'ОСЦ-1,5-9,0 оц.-Т',
#  'ОТ2ф-5,0-1,5 оц.',
#  'ОПГ-400-9,0 оц.',
#  'Опора ТУСПСММ',
#  'ОВМГ-20',
#  'Бульвар-4,5 оц.',
#  'ВМО-25/9',
#  'ВМО-20/4',
#  'ВМО-20/9',
#  'ВМО-20/5',
#  'ОПГ-700-9,0 оц.',
#  'ОСЦ-0,8-9,0',
#  'ОКК-6 оц.',
#  'Осв. система Cherry-5.0',
#  'Смарт CSM-9,0-7,0/4,0-2К оц.',
#  'Смарт CSM-9,0-7,0/4,0-1К оц.',
#  'СЦ-0,8',
#  'Флагшток',
#  'ОСТ-700-9,0/11,0-01 оц.',
#  'ОСТ-400-9,0/11,0-01 оц.',
#  'ОМ-8-Т',
#  'ОС-0,9',
#  'Торшер «Виконт-1» оц.',
#  'Опора пласт.',
#  'Смарт GSM-8,0-6,0/4,0-1К',
#  'СНЦ-7,7-12,0',
#  'ОС-1,3-9,0',
#  'КО-1-1-5,0',
#  'СНЦ-5,1-11,5',
#  'О8',
#  'ОГС-0,4-9,0 оц.',
#  'ОМ-7-Т оц.',
#  'НФГ-9,0-0,5 оц.',
#  'Проспект-9,0-111/219 оц.(МФО)',
#  'ОКК Проспект PSKT-80 СИП-400',
#  'Смарт CSM-6,0-4,0/4,0-1К оц.',
#  'неуст.',
#  'О6-А',
#  'ОКК-8,0 ф оц.',
#  'ОКК SP-8-9 оц.',
#  'СЦС-0,8-9,0',
#  'ОС-0,7-9,0 оц.-Т',
#  'ОКК SP-1-5 оц.',
#  'ОКК SP-10-7-4 оц.',
#  'ОС-0,6-9,0 оц.',
#  'ОКК SP-10-7-2 оц.',
#  'НОК-9,0 оц.',
#  'СП-400-6,0/8,0-02 оц.',
#  'ОДН «Новые башни МР»',
#  'ОВ-4,0-П1-3,3',
#  'ОВ-9,5-П2-5',
#  'ОФ',
#  'ОГК-1 оц.',
#  'ОО-3,0-Д-2-0,8',
#  'ОО-3,0-Д-4-0,8',
#  'КО-2',
#  'КО-4',
#  'ОС-0,3-8,5 оц.',
#  'ПФГ-8-к-ц',
#  'ОСЦ',
#  'ОГКС-9 оц.',
#  'Торшер СИСИ-1 оц.',
#  'Торшер «Арбат-5»',
#  'Торшер «Арбат-1»',
#  'Торшер «Арбат-3»',
#  'ОКК SP-1-4,5 оц.',
#  'Ретро-7,5',
#  'СП-700-8,5 оц.',
#  'ОПФ-700-9,0 оц.',
#  'ОДН «Русские башни»',
#  'ОКК',
#  'ОС-0,3 надстава «Новые башни МР»',
#  'ОСФ-1,5-9,5 оц.',
#  'ОКК-4,5 оц.МФО Бульвар',
#  'СЦС-0,4-9,0 оц.',
#  'НФК-7,0-0,2 оц.',
#  'СП-400-9,5/10,5-01 оц.',
#  'ОКК-8,0-02 МФО оц.',
#  'ОС-0,7-9,0 и надставка «Русские башни»',
#  'ОКК SP-9-8 оц.',
#  'ОГК-7 оц.',
#  'ОС-1,1-9,0',
#  'НУОВО ДЕО-9,0',
#  'СП-400-8,5 надставка «Новые башни МР»',
#  'ОС-0,7-9,0 ф',
#  'ОТ1-4,0-1,0',
#  'ОСТ-700-10,5-12,5 оц.',
#  'ОСФ-400-9,0 оц.',
#  'ОС-0,7-9,0 надставка «Русские башни»',
#  'О5 ус.',
#  'Т-1-М ук.',
#  'ОКК-4,5-75/150-3 оц.',
#  'МФО ОКК-4,5-75/185-3 оц',
#  'ОМ 10м',
#  'ОМ 6м',
#  'ОМ-5-9',
#  'СФГ-9,0 ф.оц.',
#  'ОККс-8,0-МФО оц.',
#  'ОСФ-700-9,5 оц.',
#  'Ф-5-П',
#  'СФ-14-02 оц. «Вертикаль»',
#  'ОМ-5 надставка «Русские башни»',
#  'ОСТ-400-8,5/10,5-01 оц.',
#  'КК-12',
#  'ОС-0,6-11,0-2В',
#  'ОС-1,0-11,0-2В',
#  'Т-5-М',
#  'ОККс-8,0-0,2 оц.',
#  'МГТ без подвеса',
#  'НОК-9,0 СИП оц.',
#  'Опора Проспект-6 оц.',
#  'ОС-0,7-9,0 надставка «Новые башни МР»',
#  'ОС-0,4-11,0 оц.',
#  'НОК-4,0 оц.',
#  'Торшер «Виконт»-5,5',
#  'Торшер «Виконт»-4,5',
#  'Т-1-Б',
#  'Торшер фонарь',
#  'КПГ',
#  'ОС-0,4-8,5',
#  'Опора МОЭСК (Д)',
#  'ВМУ-30',
#  'ВМУ-20',
#  'ТХЛ-9',
#  'ТХЛ-5',
#  'ТХЛ-1',
#  'ТХЛ-2',
#  'Торшер чуг.',
#  'СП-100-6,0/6,0-01 оц.',
#  'ОГК-4 ф',
#  'Торшер «Сарос-1»',
#  'Ф-2-М',
#  'Т-4-М',
#  'Надстав. к ОС-1,3-11,0',
#  'НФГ-7,0-0,5 оц.',
#  'ОМ-5 надставка «Новые башни МР»',
#  'Опора Балчуг И2 и надставка НГС',
#  'Опора Балчуг И2',
#  'ОВМ-22',
#  'Торшер «Балчуг И2-2»',
#  'Торшер чуг. 2-х рожк.',
#  'Торшер-тумба Т-13-Б',
#  'Торшер ЛИХБ 11.000',
#  'Торшер ЛИХБ 01.000',
#  'Торшер ЛИХБ 10.000',
#  'КК-5Г-78',
#  'ОСЦ-0,3-9,0',
#  'Ф-2-Л',
#  'МС/П-6Ф-0,25',
#  'ОСФ-0,4-9,5-02 оц.',
#  'ОТСЛ-2-2',
#  'СП-700 оц.',
#  'ОГКф-9 оц.',
#  'Осв. система Ярд 40/1 оц',
#  'ОКК SP-9-4-147 оц.',
#  'ОТК-5 оц.',
#  'ОГСф-0,4-9,0 оц.',
#  'ОГК-10 оц.',
#  'ОКК-8,0-75/171 оц.',
#  'О9',
#  'ОКК SP-9-10-212 оц.',
#  'ОСФ-0,1-4,5 Арбат',
#  'ОС-0,7-8,5 оц.',
#  'КО-2-2',
#  'ПФГ-8,0 оц.',
#  'Осв.комплекс Смарт Стик-5,0 оц.',
#  'ОККс-6,0-70/142 оц. Аллея',
#  'Т-1-М спец.',
#  'Проспект-8,0-68/180 оц.',
#  'ОГСф-0,7-9,0 оц.',
#  'ОМ-11',
#  'ОСФ',
#  'ОВМ-20',
#  'ОВМГ-30',
#  'ОКК-9 МФО Проспект оц.',
#  'МС-10Г-0,4 оц.',
#  'ОПФГ-8 оц.',
#  'КО-2-2-5',
#  'Опора Г-2 инд.изг.',
#  'Мачта Лужников',
#  'ОДер.',
#  'ФМ-05 оц.',
#  'ФМ-06 оц.',
#  'ОКК-9,0/11',
#  'ФМ-05 оц.(Т)',
#  'ФМ-06 оц.(Т)',
#  'ОКК-4ф оц.',
#  'ОККс-8,0-70/168 оц. Аллея',
#  'ОПГ-6 оц.',
#  'Бульвар BLV2-45 оц.',
#  'Хайвей Н-90/01',
#  'Осв. система Хайфа',
#  'ОВ-9,5-П2-5 оц.',
#  'Хайвей Н-90/02',
#  'СП-700-9,0/11,0-01 оц. промежут.',
#  'ООКС-400-9,0 оц.',
#  'Торшер OYB-4.0',
#  'ОС-0,3 ук.',
#  'Т-004-1',
#  'Т-004-2',
#  'ОВ-4,5-Т1-2',
#  'ОВ-4,5-Т1-1',
#  'ОО-4,5-Д-4-0,6',
#  'Т-2-08 «Апекс»',
#  'Торшер НО-СВ',
#  'Торшер ОТ-2',
#  'Торшер НО-СВ-2',
#  'Торшер НОСВ 01.010 оц.',
#  'ОС-0,4-9,0 ук. оц.',
#  'ОС-2,1-9,0',
#  'СП-400-9,0/11,0-01 оц. промежут.',
#  'Стойка',
#  'СП-400-5,0/7,0 оц.',
#  'ОВМ-33',
#  'СФ-400-4,0-02 оц.',
#  'ОГК-3(2)',
#  'ОГК-8(4)',
#  'СФ-МФО-700-9,0-02 оц.',
#  'Осв. система Cherry-45',
#  'ОКК SP-9-9 оц.',
#  'Торшер «Ангел-2»',
#  'КО-1-1-5,5',
#  'Торшер «Сокол-1»',
#  'ОТ2ф-3,5-1,0 оц.',
#  'ОККО Легато-7,0-4 оц.',
#  'СФК-400-8,0-02 оц. Проспект',
#  'СФ-400-8,5-02 оц.',
#  'Аллея AL-80',
#  'ОККО',
#  'СП-800-9,0/11 оц.',
#  'ОС-0,4-5,5 оц.',
#  'ОС-0,3-5,5 оц.',
#  'ОСЦ-0,4-9,0 ф. оц.',
#  'ОС «Иматра АС»',
#  'ОКК-9 оц.',
#  'ООМЦК-9,6',
#  'ОТ2(60)-4,5-1,5 ф. оц.',
#  'СП-400-4,0/6,0-01 оц.',
#  'ОТУ3Т',
#  'КК-12ф-75 оц.',
#  'НФГ-8,0-0,5 оц.',
#  'ОГК-3 оц.',
#  'ОТ2(60)-4,0-1,0 оц.',
#  'Торшер Элегия',
#  'Надстав.',
#  'Надстав. оц.',
#  'ОТ-КК-3Г-60',
#  'ОСС-3600/59/89/2 оц.',
#  'КО-1-1-3,0 оц.',
#  'ОБ',
#  'Торшер Сокол-2',
#  'НФГ-10-0,2 оц.',
#  'КК-5ф-60',
#  'КО-1-1-4 оц.',
#  'ОМ-6-Т ус.оц.',
#  'ОТ2-4,5-1,0 оц.',
#  'Краб',
#  'СПГ-400-9,0/11,5 оц.',
#  'Торшер СИТИ-2',
#  'КК-5ф-60(3) оц.',
#  'Торшер SPAR-1.2',
#  'ОПФК-0,4-9,0 оц.',
#  'ОС-0,6-11,0 ф оц.',
#  'ОМ-7 ус.оц.',
#  'ОМ-6 ус.оц.',
#  'СФ-700-6,0-0,2 оц.',
#  'СФ-400-6,0-0,2 оц.',
#  'ОТ2-3,5-1,0',
#  'ОГС-0,4-8,0 оц.',
#  'Торшер БОЛ 5',
#  'ОТ2-4,0-1,0 оц.',
#  'Торшер СИСИ-2 оц.',
#  'НОСВ 01.010 оц.',
#  'КО-1 оц.',
#  'Торшер «Ракита-2»',
#  'Торшер «Ракита-4»',
#  'МК-5Ф-60',
#  'ОГК-8 ф оц.',
#  'Торшер «Апекс» ТД-1',
#  'ОВ-9,6-П-5',
#  'Торшер «Адамант-3»',
#  'ОСС-3600/1',
#  'Торшер «Апекс» ТД-2',
#  'НФК-9,0-0,2 оц.',
#  'ОПГ-5 ф',
#  'ОГК-8',
#  'МГТ1',
#  'Торшер Сокол-2 оц.',
#  'Опора ТАНС.12.032.000',
#  'ПФГ-8,0-02 оц.',
#  'Торшер Зенит 159 h-4.5',
#  'ОССв 3,6-2-10В оц.',
#  'Торшер БОЛ-1-4,0 оц.',
#  'НП-4,0/5,0-0,2 оц.',
#  'ОТ-1-3,5-0,8 оц.',
#  'Торшер 003,2-Т-1-01',
#  'ОКК SP-11-9 оц.СМАРТ',
#  'ОД(Б)',
#  'ОМ-6 промеж.',
#  'ОГСКЛ-5,0 оц.',
#  'МФО-6,0-142/219',
#  'СФ-700-8,5-01 оц.',
#  'Проспект-6,0-75/151 оц.',
#  'ОК-3',
#  'ОС-0,7-5,0 оц.',
#  'НФГ-5,0-0,5 оц.',
#  'ОП-700-8,5 оц. промежут.',
#  'ОД-1-3,0 оц.',
#  'Торшер 6.Ц23.2.0',
#  'ОС-0,1-5,0-1,5 оц.',
#  'КК-5Г-60',
#  'ОПФГ-3',
#  'ОКК-4',
#  'ОТ-2-3,5-0,8 ф оц.',
#  'ОГС-0,7-9,0 оц.',
#  'ОГКС-10,5 оц.',
#  'Мачта',
#  'Торшер «Свирь»-4 оц.',
#  'ОД-6-2-0,4',
#  'ОТ1-4,5-1,0',
#  'Казань-4,0 KAZ-40',
#  'ОТ1-4,5-0,5',
#  'ОС-1,3-9,0 оц.',
#  'ОТ2-3,5-1,0 оц.',
#  'Торшер Т-09-4',
#  'СЦС-0,8 промежут.',
#  'Торшер 6.Т54.3.45.V11-01/2',
#  'ОТ2Ф(60)-3,5-1,0 оц.',
#  'КО-4-1-4,5',
#  'НФ-4,0',
#  'СКОПП-6',
#  'ОКК-5',
#  'Торшер Шар-1',
#  'ОПФ-400-5,0 оц.',
#  'Торшер Капля-1',
#  'Торшер «Шар-1»',
#  'ОГК-4 ф оц.',
#  'ОТ2-5,0-1,5 оц.',
#  'ОГК-8 оц.',
#  'МК-4Ф-60(3) оц.',
#  'ОТ-2-3,0-0,8-Т',
#  'ОКУ-1',
#  'Торшер «Сокол-2»',
#  'ОТ-1-3,0-0,8 оц.',
#  'ОТ-2-3,0-0,8',
#  'Торшер ВАНТ 5.1',
#  'Торшер БОЛ 1.2 1-рожк.',
#  'ОТ-2ф-4,0-1,5 оц.',
#  'ОТ2(60)-3,0-1,0',
#  'ОГКФ оц.',
#  'ОККс-10 оц.',
#  'Бульвар BLV45/MFO оц.',
#  'Торшер «Сайма»',
#  'СФ-700-8,5 оц.',
#  'СП-700-9,0 надставка «Русские башни»',
#  'СП-400-3,0/5,0-02 оц.укор.',
#  'ОТЗф-6,0-1,5',
#  'СВ-95 (МОЭСК)',
#  'СВ-95',
#  'ОКС-0,4-10 оц.',
#  'Бульвар BLV40/MFO оц.',
#  'ОС-0,4-8,0/10-01оц.',
#  'ОГКС-12 оц.',
#  'Торшер «Сокол-2» оц.',
#  'ОСф-700-10,5 оц.',
#  'СВ-95 (МОЭСК) ВЛ',
#  'Торшер Тверь-TV150-40/1',
#  'Торшер ОТ-4 оц.',
#  'НФГ-3,0-0,2 оц.',
#  'КО-1-1-3,5',
#  'Торшер Зенит-А-3,5',
#  'НФК-5,0-0,2 оц.',
#  'ОТ-2 оц.',
#  'ОГК-6 оц.',
#  'Торшер Платан-2',
#  'МГФ-25-(500)-111-6 оц.',
#  'МГС-20-4-М оц.',
#  'ОНО-6 оц.',
#  'Торшер Свирь-5 оц.',
#  'Торшер АПЕКС 5-8',
#  'ОС-0,4-9,0 промежут.',
#  'ОКК SP-1-6 оц.',
#  'ОС-1,0-11,0 ук. оц.',
#  'ОС-0,7-9,0 ук. оц.',
#  'ОВМ-30/4',
#  'ОВМ-30/6',
#  'ОС-1,5-9,0 ук. оц.',
#  'МСП-9Г-0,7 оц.',
#  'ОТ1-4,5-0,8 оц.',
#  'ОС-0,8-9,0 ук. оц.',
#  'НФ-4,0-02-оц.',
#  'МСП-9Г-0,4 оц.',
#  'ОСФ-0,1-4,0',
#  'ОККс-8 (Аллея AL80)',
#  'ОС-0,2-4,0-1,0 оц.',
#  'Торшер «Бульвар-4,5» оц.',
#  'Торшер «Ангел-1»',
#  'ОСС-4500 оц.',
#  'ОКГС-7 оц.',
#  'ОКГС-10 оц.',
#  'Торшер «Платан-3» оц.',
#  'НФ-4,0-02-лк',
#  'СФ-700-8,5-02 оц.',
#  'Камертон-12',
#  'ОП2-4,0-1,0 оц.',
#  'НФГ-11,8 оц.',
#  'Торшер «Реплей 159М»',
#  'ОП3Ф-6,0 оц.',
#  'ОД-2-6-52 оц.',
#  'ОФП-2',
#  'ОФП-1',
#  'ОПЗФ-6,0 оц.',
#  'ОКК-5,0-76/147 оц.',
#  'ПФГ-12,0 оц.',
#  'Опора чугун.',
#  'МГФ-16-М-3 оц.',
#  'ПФГ-6,0 оц.',
#  'МГФ-16-М-5 оц.',
#  'ОД-1-3,6-75 оц.',
#  'ОД-1-3,6-76 оц.',
#  'Торшер Сокол-1оц.',
#  'СФГ-400-5,0 оц',
#  'ОСТ-700-9,0/11,0-02 оц.',
#  'Торшер «Витязь-1»',
#  'ОНФГ-9,0-02 оц.',
#  'ОСЦ-1,2-9,0',
#  'ОКК-5ф оц.',
#  'ОТ2-4,5-0,8 оц.',
#  'Опора ТАНС 12.032.000 оц.',
#  'СКОПП AL/ST-2,0',
#  'СФ-400-6,0 оц.',
#  'ОССв 3,8 оц.',
#  'ОССв 3,6-1 оц.',
#  'Торшер «Сайма-60»',
#  'ОССв 3,6-2 оц.',
#  'СТО-12,0 оц.',
#  'ОД-1-4,0-77 оц.',
#  'НП-300-5,0/6,0-0,2 оц.',
#  'ОСТ-400-9,0/11,0-02 оц.',
#  'СТО-7,0 оц.',
#  'ОТ-0,3/4,0-02 оц.',
#  'ОТ2ф-3,0 оц.',
#  'СФ-400-4,5 оц.',
#  'ОП-5-3,75 оц.',
#  'ОП-5-2,55 оц.',
#  'Торшер «Сайма-50»',
#  'Опора «Сегежа»',
#  'НФГ-8,0-0,15 оц.',
#  'ОССв-400',
#  'ОП1-3,5-1,0 оц.',
#  'Рондо RON2/1',
#  'ОТЗ-9,0/11 оц.',
#  'МГФ-25-М-250-1-6 оц.',
#  'ОП1-3,5-0,8 оц.',
#  'Осв. система Старт Al80/1',
#  'ОП-0,4-4,0 оц.',
#  'СТО-7800',
#  'Торшер 1.Т.01-16 2-х рожк.',
#  'ОСЦ-1,9-11,0',
#  'ОГКС-8 оц.',
#  'Торшер ОТ-1 «Гиголайт» оц.',
#  'О3 (МОЭСК)',
#  'ОД-1-3,8-72«Бол-1» оц.',
#  'ОТ2-48-4,5-1,0 оц.',
#  'ОТ 3-9/11 оц.',
#  'ОПФГ-4 оц.',
#  'ОНО-5 оц.',
#  'Торшер «Сайма-50»-2',
#  'ОП2-5,0-1,0 оц.',
#  'Смарт CSM-8,0-6,0/4,0-2К оц.',
#  'Смарт CSM-8,0-6,0/4,0-1К оц.',
#  'СВН-9 (МОЭСК)',
#  'ОТЗ-5,0 оц',
#  'МГФ-16-М-(500)-11-6 оц.',
#  'ОТ1ф-3,5-1,0 оц.',
#  'НФГ-7,0-0,2 оц.',
#  'ОТ1ф-1-4,0 оц.',
#  'ОТ1ф-2,5-0,8 оц.',
#  'СФ-400-11,0-01 оц.',
#  'Торшер ОТК3',
#  'ОД-6-2-1,0 ф',
#  'НФ-3,8-0,2 оц.',
#  'Торшер Т-09-2',
#  'Торшер Сокол- 5',
#  'Торшер БОЛ 2.1 3-х рожк.',
#  'Ф-1-М',
#  'Опора коническая',
#  'ОТ1-4,0-1,0 оц.',
#  'Торшер Ангел-1',
#  'ОПФ2-4,0-1,0 оц.',
#  'Торшер БОЛ 2.2 3-х рожк.',
#  'Торшер Ангел-3.2',
#  'НПГ-3 оц.',
#  'НПГ-5 оц.',
#  'Торшер «Огонек-2» оц.',
#  'ОГК-4',
#  'Торшер БОЛ-1-5,0',
#  'Торшер «Огонек-1» оц.',
#  'ОТ1 Ф-4,0-1,0 оц.',
#  'ОТЗ-6,0-1,5 оц',
#  'Опора МОЭСК (М)',
#  'НПГ-9/11,0-02 оц.',
#  'ОККс-6 (1) Смарт',
#  'СПГ-700-9,0/11,5 оц.',
#  'НФ-4,0-02-Ф2оц.',
#  'ОГСКЛ-6,0 оц.',
#  'ОТЛ1-ТЛ2',
#  'Опора Свирь',
#  'Торшер «Корсар-2»',
#  'Торшер «Рейн» оц.',
#  'СТО-9,0 оц.',
#  'ОПФГ-12 оц.',
#  'СФГ-400-7,5/10-02оц',
#  'Торшер «Рейн»-3 оц.',
#  'ОПФГ-16 оц.',
#  'ОТ-1-3,2-0,8 оц.',
#  'Торшер «Рейн»-2 оц.',
#  'Торшер «Паркад»-2 оц.',
#  'ОВМГ-30/4',
#  'Торшер «Паркад»-1 оц.',
#  'ОПФГ-7 оц.',
#  'Торшер «Лигово»',
#  'ОГКС-20 оц.',
#  'ОС-0,4-8,5/10-02оц',
#  'ОС-0,4-5,0 оц.',
#  'МГФ-30 оц.',
#  'ОМСК-18ф',
#  'ОКК-6 ф оц.',
#  'Торшер «Зенит» оц.',
#  'ОГКС-6 оц.',
#  'Торшер 2.Т04.3.0.0',
#  'Осв. система Вишенка-3-8,0',
#  'СФГ-400-8,5/11-01оц',
#  'Осв. система Оредеж',
#  'ОДН «ТехноСити»',
#  'Торшер МАС-Ф1',
#  'Торшер МАС-Ф2',
#  'СФГ-400-4,0-0,2 оц',
#  'Торшер БОЛ 1.1-01',
#  'Торшер А-03-3,5',
#  'Торшер БОЛ 1.1',
#  'Торшер БОЛ-2-4,0 оц.',
#  'Торшер «Сайма-60»-2',
#  'ОС-0,4-8,5 ф оц.',
#  'ОКК SP-1-1-5 оц.',
#  'Торшер «Оредеж» оц.',
#  'СПГ-400-8,0/10-01 оц.',
#  'Мачта 10м под 4 св-ка',
#  'ОКС-6',
#  'ОТЛ1-ТЛ2-2',
#  'ОП1-4,5-1,0 оц.',
#  'SIEMENS-30-6',
#  'SIEMENS-30-10',
#  'SIEMENS',
#  'МО-30-550-М-25С',
#  'MS',
#  'ANTARES-P60-8 оц.',
#  'AURIGA-EX-60-4 оц.',
#  'ОС-61-RLS-ф оц.',
#  'Торшер 5NY23173KMOO оц.',
#  'Торшер V09/2',
#  'Торшер Auriga P-3,5 оц.',
#  'Торшер Auriga P-4 оц.',
#  'Торшер V08-01/1',
#  'Торшер V14-10/1',
#  'Торшер V24-1/1 оц.',
#  'Торшер «Колизей-2»',
#  'ОТФ-4,0-1,25 оц.',
#  'АР-1-1-5-63-SE',
#  'Опора «Зенит 159»',
#  'НФ-5,0-02-оц.',
#  'Опора «Зенит»Z40',
#  'ОКК-5 оц.',
#  'Торшер 2.Ц13.7.0',
#  'СФ-700-10,5-02 оц.',
#  'Торшер V14-01/2',
#  'Торшер 2.Ц14-1.1.49.V14-01/02',
#  'ОТФ1-4,0-02 оц.',
#  'СФ-400-11,0-02 оц.',
#  'ОККс-8,0-70/182 оц.',
#  'ОТФ-6,0 оц.',
#  'Торшер Бульвар',
#  'СП-400-4,0/6,0-02 оц.укор.',
#  'Торшер OYB-1-4,0 оц.',
#  ...]

# %%
# снесем первую строку
df = df.drop(index=0).reset_index(drop=True)
df.head()
# Out:
#    global_id ID      PillarMark         PillarType LightsNumber        Status  \
# 0  170458093  1  ОП-400-8,5 оц.  Опора стандартная            1  эксплуатация
# 1  170458094  2  ОП-400-8,5 оц.  Опора стандартная            1  эксплуатация
# 2  170458095  3  ОП-400-8,5 оц.  Опора стандартная            1  эксплуатация
# 3  170458096  4  ОП-400-8,5 оц.  Опора стандартная            1  эксплуатация
# 4  170458097  5            ОМ-5  Опора стандартная            1  эксплуатация
#
#   OnTerritoryOfMoscow                                  AdmArea  \
# 0                  да  Северо-Восточный административный округ
# 1                  да  Северо-Восточный административный округ
# 2                  да  Северо-Восточный административный округ
# 3                  да  Северо-Восточный административный округ
# 4                  да  Северо-Восточный административный округ
#
#          District  Year BalanceHolderName OperationOrganizationName  \
# 0  район Бибирево  2003               NaN                       NaN
# 1  район Бибирево  2003               NaN                       NaN
# 2  район Бибирево  2003               NaN                       NaN
# 3  район Бибирево  2003               NaN                       NaN
# 4  район Бибирево  1997               NaN                       NaN
#
#                                              geoData geodata_center  \
# 0  {coordinates=[37.609186415, 55.902418871], typ...            NaN
# 1  {coordinates=[37.608862778, 55.902201086], typ...            NaN
# 2  {coordinates=[37.608572113, 55.901982795], typ...            NaN
# 3  {coordinates=[37.608164794, 55.901698737], typ...            NaN
# 4  {coordinates=[37.607808233, 55.901435855], typ...            NaN
#
#    Unnamed: 14
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df['geoData'] = df['geoData'].str.replace('{', '')
df['geoData'] = df['geoData'].str.replace('}', '')
df['geoData'] = df['geoData'].str.replace('], type=Point', '')
df['geoData'] = df['geoData'].str.replace('coordinates=[', '')


df['geoData'].iloc[0]
# Out:
# '37.609186415, 55.902418871'
