# %% [markdown]
# Анализ данных по дтп

# %%
import pandas as pd

# %%
df = pd.read_csv('data/accidents_all_regions_126_v20240621.csv', sep=';')
df.head()
# Out:
#         id                                               tags  \
# 0  2869171                  Дорожно-транспортные происшествия
# 1  2320091  Дорожно-транспортные происшествия, ДТП и постр...
# 2  2321011  Дорожно-транспортные происшествия, ДТП и постр...
# 3  2576909                  Дорожно-транспортные происшествия
# 4  2547743                  Дорожно-транспортные происшествия
#
#             category          region   county  \
# 0  Наезд на пешехода  Алтайский край  Барнаул
# 1       Иной вид ДТП  Алтайский край  Барнаул
# 2  Падение пассажира  Алтайский край  Барнаул
# 3       Столкновение  Алтайский край  Барнаул
# 4       Столкновение  Алтайский край  Барнаул
#
#                                              address  longitude   latitude  \
# 0                                                NaN  83.787900  53.391200
# 1                        г Барнаул, ул Сиреневая, 11  83.666389  53.345833
# 2                          г Барнаул, ул Попова, 165  83.396880  53.197060
# ...
